– Cologne Central Mosque – Compulsory Miseducation – Concealed shoes – Cone sisters – Conway, Samuel – Crinoline – Crypt of Civilization – Cultural depictions of spiders – Culture of the Cook Islands – Death in Singapore – Death of Jeffrey Epstein – Destruction of ivory – Disgusted of Tunbridge Wells – Dolphin drive hunting – Double burden – Dreamtime (book) – Dulębianka, Maria – Engineer boot – Entertainment – EST and The Forum in popular culture – Elixir (perfume) – Extremely online – Family structure in the United States – First World – Flitch of bacon custom – Foreign workers in Saudi Arabia – Freemasonry and women – Furry convention – Gay bathhouse – Genevieve Lhermitte – Giurchescu, Anca – Globalization and women in China – Goathouse Refuge – Hassan Al Kontar – Heat (perfume) – Heritage preservation in South Korea – Hernandez, Aileen – Ho Yuen Hoe – Homme by David Beckham – Hooray Henry – Hotel Europa – How to Blow Up a Pipeline – Intercrural sex – Itliong, Larry – Janet Jackson as a gay icon – Jayne Mansfield in popular culture – Jewellery of the Berber cultures – Joint attention – Kato, Sogen – Khanjar – Lang, Marie – Lesbian – Madzimbamuto, Stella – Manal al-Sharif – Manasollasa – Mari Lwyd – Meade, David – Metal corset – Metallic Metals Act – Mormon folklore – Mussie – Mutiny of the Matoika – Native American mascot controversy – New World Order (conspiracy theory) – Ni Yulan – Nonviolent Communication – Otaku – Overhill Cherokee – Pastel QAnon – Pi de les Tres Branques – Pizzagate conspiracy theory – Plastic Brit – Plumlee, Sybil – Polyethnicity – Project Chanology – The Psychology of The Simpsons – QAnon – Reborn doll – Redskin – Requiem for a Species – Rise (perfume) – S by Shakira – Same-sex marriage in Maryland – Sarria, José – Sarsour, Linda – Saviola, Marilyn – Sea in culture – Sexual abuse by yoga gurus – Sheng nu – Sikh diaspora – Sindy – Slavery in Haiti – Smith, Mary Stuart – Smoking in North Korea – Social heuristics – Soljak, Miriam – Sorensen, Jacki – Spirit Fruit Society – Squatting in Thailand – Squatting in the Czech Republic – Squatting in the Netherlands – Squatting in the Philippines  – Squatting in Ukraine – Stay-at-home dad – Steinem, Gloria – Still Jennifer Lopez – Tamimi, Ahed – Telpuk, María del Luján – Tewkesbury Medieval Festival – Think of the children – Three Sisters Tavern – Thunberg, Greta – Tinne, Emil ...

# %% [markdown]
# ## Installing libraries for downloading wikipedia pages and formatting.

# %%
# !pip install wikipedia-api 
# !pip install tabulate
! pip install gensim
# Out:
# Requirement already satisfied: wikipedia-api in /usr/local/lib/python3.7/dist-packages (0.5.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from wikipedia-api) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->wikipedia-api) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->wikipedia-api) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->wikipedia-api) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->wikipedia-api) (2.10)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (0.8.9)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.5)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)

# %%
import wikipediaapi
wiki_wiki = wikipediaapi.Wikipedia('en')

# %% [markdown]
# ## TF_IDF Alogorithm

# %% [markdown]
# ### Text Preprocessing for TF-IDF

# %%
def keep_up_freq(old_list, min_count):
  dictionary = {}
  for word in old_list:
    if word in dictionary:
      dictionary[word]+=1
    else:
      dictionary[word]=1
  new_list = list(filter(lambda x: dictionary[x]>=min_count,dictionary.keys()))

  return new_list

# %% [markdown]
# ### Creating Inverted Index for TF-IDF

# %%
## Reading stopwords from a file.
from nltk.stem import PorterStemmer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re

english_stopwords = stopwords.words('english')
ps = PorterStemmer()
delimiters = " ","\s", "." , ";" , ":" ,"'", "," , "\"", "\n","[","]","}","{",")","("
regexPattern = '|'.join(map(re.escape, delimiters))

## Creating a dictionary
word_dictionary = {}
word_freq = {}

for i in range(N_phrases):
  print(i,phrases_list[i])
  try:
    visited_words_in_doc = set()
    article_content = wiki_wiki.page(phrases_list[i]).text
    ## creating a list of words for each article
    article_content_word_list = list(map(lambda x: x.lower(),re.split(regexPattern, article_content)))
    article_content_word_list = list(filter(lambda x: x not in english_stopwords and x.isalpha(), article_content_word_list))
    article_content_word_list = list(map(lambda x: ps.stem(x),article_content_word_list))
    ##cleaned_text_dict[phrases_list[i]] = article_content_word_list
    doc_reduced_length = len(article_content_word_list)

    for word in article_content_word_list:
      if word not in word_freq:
        word_freq[word] = 1
      else:
        word_freq[word] += 1
      if word in visited_words_in_doc:
        continue
      else:
        visited_words_in_doc.add(word)
      if word not in word_dictionary:
        word_dictionary[word] = [[phrases_list[i],article_content_word_list.count(word)/doc_reduced_length]]
      else:
        word_dictionary[word].append([phrases_list[i],article_content_word_list.count(word)/doc_reduced_length])

  except:
    continue
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0 Fettiplace, Elinor
# 1 Gerber, Daniel Frank
# 2 Guinness, Arthur
# 3 Hill, Georgiana
# 4 Hunziker, Otto Frederick
# 5 Lawson, Nigella
# 6 P. Halfhill, Albert
# 7 Pepper, Charles T.
# 8 Petty, Florence
# 9 Philippe, Claude
# 10 Roux, Michel
# 11 Rückerschöld, Anna Maria
# 12 Tremo, Paul
# 13 Women in brewing
# 14 Mario Peruzzi-Elizabeth David bibliography
# 15 The Art of Cookery Made Plain and Easy
# 16 A Book of Mediterranean Food
# 17 Compendium ferculorum, albo Zebranie potraw
# 18 The Compleat Housewife
# 19 The Cookery Book of Lady Clark of Tillypronie
# 20 The Experienced English Housekeeper
# 21 Food in England
# 22 The Good Huswifes Jewell
# 23 The Modern Cook
# 24 Modern Cookery for Private Families
# 25 Mrs. Beeton's Book of Household Management
# 26 A New System of Domestic Cookery
# 27 The Accomplisht Cook-Apple Maggot Quarantine Area
# 28 Arab Agricultural Revolution
# 29 Butler café
# 30 Cellarette
# 31 French fry vending machine
# 32 Makiyakinabe
# 33 Pancake machine
# 34 Wet market
# 35 1950s American automobile culture
# 36 Acting white
# 37 Afternoon
# 38 Alcohol and Native Americans
# 39 Alcoholic beverages in Oregon
# 40 Algorithmic bias
# 41 Ali, Nimco
# 42 Anthony, Susan B. II
# 43 Anti-nuclear movement in Australia
# 44 Arizmendi Mejia, Elena
# 45 Astrology
# 46 Ave Imperator, morituri te salutant
# 47 Bailey, Frank (firefighter)
# 48 Banditti of the Prairie
# 49 Banglapedia
# 50 Bednar, David
# 51 Benet de Mewton, Milagros
# 52 Bic Cristal
# 53 Bikini
# 54 Body piercing
# 55 Boerehaat
# 56 Boobrie
# 57 Bosnian genocide denial
# 58 Breaker boy
# 59 Brownie Mary
# 60 Bugchasing
# 61 Cannabis in Japan
# 62 Cannabis in Oregon
# 63 Campbell, Bobbi
# 64 Campbell, John Gregorson
# 65 Child prostitution
# 66 Chongqing model
# 67 Clussexx Three D Grinchy Glee
# 68 Cologne Central Mosque
# 292 Indian Institute of Management Rohtak
# 293 Jesus College, Oxford
# 294 Johnson Senior High School (Saint Paul, Minnesota)
# 295 King's College London
# 296 King's University College (University of Western Ontario)
# 297 Klein Independent School District
# 298 Lafayette College
# 299 Lindenwood University
# 300 Litchfield Towers
# 301 Mackinac College
# 302 Malvern College
# 303 Marriott School of Business
# 304 Massachusetts Institute of Technology
# 305 McMaster University
# 306 Midwestern University
# 307 Monmouth School for Boys
# 308 Nan Chiau High School
# 309 New Brunswick Theological Seminary
# 310 North Community High School
# 311 Norwich School
# 312 Nova Southeastern University
# 313 Oxford College of Emory University
# 314 Pathlight School
# 315 Port Charlotte High School
# 316 Presbyterian Ladies' College, Sydney
# 317 Providence College
# 318 Pūnana Leo
# 319 Queen's University at Kingston
# 320 Romney Academy
# 321 Romney Classical Institute
# 322 Rosenstiel School of Marine and Atmospheric Science
# 323 Roswell High School (Georgia)
# 324 Royal Grammar School, Guildford
# 325 St George's Academy
# 326 Scarborough Day School
# 327 School of Advanced Military Studies
# 328 Seal of Dartmouth College
# 329 Seton Hall University
# 330 Southern Adventist University
# 331 State University of Campinas
# 332 Stonyhurst College
# 333 Summerhill (book)
# 334 Syracuse University
# 335 Technology Center (Washington & Jefferson College)
# 336 Telluride House
# 337 Texas State University
# 338 Thayer School of Engineering
# 339 The Culinary Institute of America
# 340 The Culinary Institute of America at Greystone
# 341 Theodore Roosevelt High School (Kent, Ohio)
# 342 Trump University
# 343 Union City High School (New Jersey)
# 344 University College, Durham
# 345 University of Bristol
# 346 University of Calcutta
# 347 University of California, Santa Cruz
# 348 University of Central Florida
# 349 University of Colorado Denver
# 350 University of Edinburgh
# 351 University of Houston
# 352 University of Miami
# 353 University of Mississippi
# 354 University of Missouri School of Music
# 355 University of North Carolina at Chapel Hill
# 356 University of North Dakota
# 357 University of Oxford
# 358 University of Surrey
# 359 University of the Philippines Los Baños
# 360 University of the Philippines Los Baños College of Forestry and Natural Resources
# 361 University of Toronto
# 362 University of Valle
# 363 University of Wisconsin Experimental College
# 364 Washington & Jefferson College
# 365 Western University of Health Sciences
# 366 Whitney High School (Rocklin, California)
# 367 Widener Library
# 368 Willamette University College of Law
# 369 Wisbech Grammar School

# %% [markdown]
# ### Responding to queries using TF-IDF Algorithm

# %%
import math
from tabulate import tabulate
Queries = ["India","USA","wheat"]

def TF_IDF_search(query,english_stopwords,word_freq,N_phrases,word_dictionary):
  url_prefix = "https://en.wikipedia.org/wiki/"
  ps = PorterStemmer()
  search_word = query
  query = ps.stem(query)
  if query in english_stopwords:
    print("Please give a more specific query for ", search_word)
  if query not in word_freq:
    print("Sorry! No good search available for ",search_word)
  else:
    Query_result_list = []
    IDF = math.log2(N_phrases/word_freq[query])
    sorted_doc_list = sorted( word_dictionary[query] , key = lambda x: x[1], reverse = True)
    print("Results for your query ", search_word ," are:")
    for rank, result in enumerate(sorted_doc_list):
      score = result[1]
      Query_result_list.append([rank+1,score, result[0], url_prefix+result[0].replace(" ","_")])

    Header = ["Rank","TF-IDF Score","Article Heading","Link"]

    print(tabulate(Query_result_list , headers=Header, tablefmt="grid"))

# %% [markdown]
# ## WORD2VEC

# %% [markdown]
# ### Learning the contexts in corpus using Skip Gram Algorithm

# %%
# Python program to generate word vectors using Word2Vec
  
# importing all necessary modules

cleaned_text_dict = {}
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings
nltk.download('stopwords')
nltk.download('punkt')
warnings.filterwarnings(action = 'ignore')
import gensim
from gensim.models import Word2Vec

#CBOW_model1 = gensim.models.Word2Vec(min_count = 1, size = 100, window = 5)
Global_words_collection = []

for phrase_number in range (N_phrases):
  sample = wiki_wiki.page(phrases_list[phrase_number]).text
  without_new_line_sample = sample.replace("\n", " ")
  cleaned_text_dict[phrases_list[phrase_number]] = []
    
  # iterate through each sentence in the file
  for i in sent_tokenize(without_new_line_sample):
      temporary_token_storage = []
      for j in word_tokenize(i):
          if j.lower() not in english_stopwords: 
            temporary_token_storage.append(ps.stem(j.lower()))
      Global_words_collection.append(temporary_token_storage)
      cleaned_text_dict[phrases_list[phrase_number]] += temporary_token_storage

Skip_Gram_model2 = gensim.models.Word2Vec(Global_words_collection, min_count = 1, size = 100, window = 5, sg =1)

doc_vectors = {}
for phrase in phrases_list:
  if phrase not in cleaned_text_dict or len(cleaned_text_dict[phrase])==0:
    continue
  doc_vectors[phrase] = sum(list(map(lambda x: Skip_Gram_model2.wv[x], cleaned_text_dict[phrase])))/len(cleaned_text_dict[phrase])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Vocabulary size
print('Vocabulary size is:', len(Skip_Gram_model2.wv.vocab))
# Out:
# Vocabulary size is: 53905

# %% [markdown]
# ### Responding to queries using Word2Vec

# %%
import numpy

def Word2Vec_search(query,english_stopwords,Skip_Gram_model2,cleaned_text_dict,doc_vectors,phrases_list):
  url_prefix = "https://en.wikipedia.org/wiki/"
  ps = PorterStemmer()

  search_word = query
  query = query.split(" ")
  query = list(map(lambda x: ps.stem(x.lower().strip()),query))
  query = list(filter(lambda x: x not in english_stopwords,query))
  if len(query)==0:
    print("Please give a more specific query for ", search_word)
  else:
    Query_result_list = []
    query_vector = sum(list(map(lambda x: Skip_Gram_model2.wv[x], query)))/len(query)
    similar_words=  Skip_Gram_model2.most_similar(positive = [query_vector], topn=10)
    print( " You may also like to search:  " )
    for similar_term in similar_words:
      print("-----> ",similar_term)
    for phrase in phrases_list:
      if phrase not in cleaned_text_dict or len(cleaned_text_dict[phrase])==0:
        continue
      document_vector = doc_vectors[phrase]
      cosine_similarity = numpy.dot(document_vector, query_vector)/(numpy.linalg.norm(query_vector)* numpy.linalg.norm(document_vector))
      Query_result_list.append([cosine_similarity, phrase,url_prefix+phrase.replace(" ","_")])
      
    Query_result_list = sorted(Query_result_list , key = lambda x: x[0], reverse =True)
    print("Top 50 results for your query ", search_word ," are:")
    for rank, result in enumerate(Query_result_list):
      Query_result_list[rank] = [rank+1] + Query_result_list[rank]

    Header = ["Rank","Similarity Score","Article Heading","Link"]
    return tabulate(Query_result_list[0:50] , headers=Header, tablefmt="grid")

# %%
def Text_search(query, algo):
  if algo == 0:
    print(TF_IDF_search(query,english_stopwords,word_freq,N_phrases,word_dictionary))
  else:
    print(Word2Vec_search(query,english_stopwords,Skip_Gram_model2,cleaned_text_dict,doc_vectors,phrases_list))

# %%
import time
start_time = time.time()
Text_search("Agriculture", 0)
end_time = time.time()
print("Time taken for TF-IDF is ", end_time-start_time," s")
# Out:
# Results for your query  Agriculture  are:
# +--------+----------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------+
#


# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install speechrecognition
# Out:
# Requirement already satisfied: speechrecognition in /usr/local/lib/python3.7/dist-packages (3.8.1)

# %%
# This will take voice input as WAV format .
import speech_recognition as sr

# initialize the recognizer
r = sr.Recognizer()

path = "/content/drive/MyDrive/MTL782/voice.wav"
# open the file
retrived_text = ""
with sr.AudioFile(path) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    retrived_text = text.replace("'s","");
    #print(text)

# %%
Text_search(retrived_text,1)
# Out:
#  You may also like to search:
# ----->  ('methodolog', 0.9631109237670898)
# ----->  ('broader', 0.9572066068649292)
# ----->  ('vba', 0.9570857286453247)
# ----->  ('outcom', 0.9566575288772583)
# ----->  ('effici', 0.9535539746284485)
# ----->  ('balanc', 0.9531266689300537)
# ----->  ('mandat', 0.9530009627342224)
# ----->  ('output', 0.9526617527008057)
# ----->  ('furthermor', 0.9526267051696777)
# ----->  ('systemat', 0.9525909423828125)
# Top 50 results for your query  am I India system is a system capable of processing multimedia data and applications  are:
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |   Rank |   Similarity Score | Article Heading                                                           | Link                                                                                                    |
# +========+====================+===========================================================================+=========================================================================================================+
# |      1 |           0.950083 | Algorithmic bias                                                          | https://en.wikipedia.org/wiki/Algorithmic_bias                                                          |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      2 |           0.947142 | Veterans benefits for post-traumatic stress disorder in the United States | https://en.wikipedia.org/wiki/Veterans_benefits_for_post-traumatic_stress_disorder_in_the_United_States |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      3 |           0.944995 | Social heuristics                                                         | https://en.wikipedia.org/wiki/Social_heuristics                                                         |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      4 |           0.939096 | Joint attention                                                           | https://en.wikipedia.org/wiki/Joint_attention                                                           |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      5 |           0.935731 | Cannabis in Japan                                                         | https://en.wikipedia.org/wiki/Cannabis_in_Japan                                                         |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      6 |           0.935363 | Foreign domestic helpers in Hong Kong                                     | https://en.wikipedia.org/wiki/Foreign_domestic_helpers_in_Hong_Kong                                     |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      7 |           0.933904 | Wet market                                                                | https://en.wikipedia.org/wiki/Wet_market                                                                |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      8 |           0.931088 | Foreign workers in Saudi Arabia                                           | https://en.wikipedia.org/wiki/Foreign_workers_in_Saudi_Arabia                                           |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |      9 |           0.930404 | Destruction of ivory                                                      | https://en.wikipedia.org/wiki/Destruction_of_ivory                                                      |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     10 |           0.928588 | Bugchasing                                                                | https://en.wikipedia.org/wiki/Bugchasing                                                                |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     11 |           0.928585 | Nonviolent Communication                                                  | https://en.wikipedia.org/wiki/Nonviolent_Communication                                                  |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     12 |           0.92822  | Alcohol and Native Americans                                              | https://en.wikipedia.org/wiki/Alcohol_and_Native_Americans                                              |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     13 |           0.92737  | Pastel QAnon                                                              | https://en.wikipedia.org/wiki/Pastel_QAnon                                                              |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     14 |           0.926479 | Vietnamese Cambodians                                                     | https://en.wikipedia.org/wiki/Vietnamese_Cambodians                                                     |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     15 |           0.926057 | Metallic Metals Act                                                       | https://en.wikipedia.org/wiki/Metallic_Metals_Act                                                       |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     16 |           0.925981 | Requiem for a Species                                                     | https://en.wikipedia.org/wiki/Requiem_for_a_Species                                                     |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     17 |           0.925153 | Smoking in North Korea                                                    | https://en.wikipedia.org/wiki/Smoking_in_North_Korea                                                    |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |
                          |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     45 |           0.910555 | QAnon                                                                     | https://en.wikipedia.org/wiki/QAnon                                                                     |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     46 |           0.909929 | Dreamtime (book)                                                          | https://en.wikipedia.org/wiki/Dreamtime_(book)                                                          |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     47 |           0.909784 | Dolphin drive hunting                                                     | https://en.wikipedia.org/wiki/Dolphin_drive_hunting                                                     |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     48 |           0.909685 | Astrology                                                                 | https://en.wikipedia.org/wiki/Astrology                                                                 |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     49 |           0.909672 | Sheng nu                                                                  | https://en.wikipedia.org/wiki/Sheng_nu                                                                  |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+
# |     50 |           0.909347 | Alcoholic beverages in Oregon                                             | https://en.wikipedia.org/wiki/Alcoholic_beverages_in_Oregon                                             |
# +--------+--------------------+---------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------+

# %% [markdown]
# ##*Video Part*

# %%
# !pip install ffmpeg moviepy
import moviepy.editor as mp
# Out:
# Requirement already satisfied: ffmpeg in /usr/local/lib/python3.7/dist-packages (1.4)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (0.2.3.5)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy) (4.64.0)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy) (2.4.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from moviepy) (1.21.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy) (7.1.2)

# %%
my_clip = mp.VideoFileClip(r"/content/drive/MyDrive/MTL782/srilanka2.mp4")

# %%
my_clip.audio.write_audiofile(r"/content/drive/MyDrive/MTL782/my_result.wav")
# Out:
# [MoviePy] Writing audio in /content/drive/MyDrive/MTL782/my_result.wav
# 100%|██████████| 282/282 [00:00<00:00, 1464.16it/s]
# [MoviePy] Done.

# %%
# This will take voice input as WAV format .
import speech_recognition as sr

# initialize the recognizer
r = sr.Recognizer()

path = "/content/drive/MyDrive/MTL782/my_result.wav"
# open the file
retrived_text = ""
with sr.AudioFile(path) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    retrived_text = text.replace("'s","");
    print(retrived_text)
# Out:
# editions of the current flag which was used for the 1951 the additional colors but then added as representation of Sri Lankan tamil and Muslims

# %%
Text_search(retrived_text,1)
# Out:
#  You may also like to search:
# ----->  ('croatia', 0.9639039039611816)
# ----->  ('margin', 0.9601020812988281)
# ----->  ('multilingu', 0.9600788950920105)
# ----->  ('self-identif', 0.9562980532646179)
# ----->  ('self-report', 0.9557507038116455)
# ----->  ('remnant', 0.9550913572311401)
# ----->  ('navajo', 0.9547847509384155)
# ----->  ('overwhelm', 0.9547449946403503)
# ----->  ('lakota', 0.9538006782531738)
# ----->  ('istrian', 0.9533618688583374)
# Top 50 results for your query  editions of the current flag which was used for the 1951 the additional colors but then added as representation of Sri Lankan tamil and Muslims  are:
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |   Rank |   Similarity Score | Article Heading                       | Link                                                                |
# +========+====================+=======================================+=====================================================================+
# |      1 |           0.972634 | Sri Lankan Tamils                     | https://en.wikipedia.org/wiki/Sri_Lankan_Tamils                     |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |      2 |           0.967769 | Polyethnicity                         | https://en.wikipedia.org/wiki/Polyethnicity                         |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |      3 |           0.967162 | Coast Veddas                          | https://en.wikipedia.org/wiki/Coast_Veddas                          |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |      4 |           0.965524 | Cornish people                        | https://en.wikipedia.org/wiki/Cornish_people                        |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |      5 |           0.963902 | Greeks                                | https://en.wikipedia.org/wiki/Greeks                                |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |

# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     39 |           0.950611 | Mikea people                          | https://en.wikipedia.org/wiki/Mikea_people                          |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     40 |           0.950275 | Japanese settlement in Palau          | https://en.wikipedia.org/wiki/Japanese_settlement_in_Palau          |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     41 |           0.95009  | Polish minority in the Czech Republic | https://en.wikipedia.org/wiki/Polish_minority_in_the_Czech_Republic |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     42 |           0.950009 | Whaling in the Faroe Islands          | https://en.wikipedia.org/wiki/Whaling_in_the_Faroe_Islands          |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     43 |           0.949936 | Bugchasing                            | https://en.wikipedia.org/wiki/Bugchasing                            |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     44 |           0.949791 | Weapon dance                          | https://en.wikipedia.org/wiki/Weapon_dance                          |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     45 |           0.949684 | Dolphin drive hunting                 | https://en.wikipedia.org/wiki/Dolphin_drive_hunting                 |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     46 |           0.949371 | Cannabis in Japan                     | https://en.wikipedia.org/wiki/Cannabis_in_Japan                     |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     47 |           0.949106 | Arab Agricultural Revolution          | https://en.wikipedia.org/wiki/Arab_Agricultural_Revolution          |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     48 |           0.949007 | Sakhalin Koreans                      | https://en.wikipedia.org/wiki/Sakhalin_Koreans                      |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     49 |           0.948753 | Pastel QAnon                          | https://en.wikipedia.org/wiki/Pastel_QAnon                          |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+
# |     50 |           0.948486 | Matrilineal society of Meghalaya      | https://en.wikipedia.org/wiki/Matrilineal_society_of_Meghalaya      |
# +--------+--------------------+---------------------------------------+---------------------------------------------------------------------+

# %% [markdown]
# ##**Video to Images**

# %%
#Loading Image Prediction Models


import pickle
from joblib import dump,load
kmeans=load('/content/drive/MyDrive/MTL782/kmeans.joblib')
with open('/content/drive/MyDrive/MTL782/parrot.pickle', 'rb') as f:
  [preprocessed_image, images] = pickle.load(f)

def resize(image):
  height,width=image.shape
  ratio=height/width

  if height>1000 or width>1000:
    if height>width:
      h=1000
      w=math.floor(1000/ratio)
      image=cv2.resize(image,(w,h))
    else:
      w=1000
      h=math.floor(w*ratio)
      image=cv2.resize(image,(w,h))
  return image

def features(image, extractor):
    keypoints, descriptors = extractor.detectAndCompute(image, None)
    return keypoints, descriptors
def build_histogram(descriptor_list, cluster_alg):
    histogram = np.zeros(len(cluster_alg.cluster_centers_))
    cluster_result =  cluster_alg.predict(descriptor_list)
    for i in cluster_result:
        histogram[i] += 1.0
    return histogram

extractor=cv2.SIFT_create(nfeatures = 50)

def query(query_image):
    query_image=resize(query_image)
    start_time = time.time()
    keypoint, descriptor = features(query_image, extractor)


    histogram = build_histogram(descriptor.astype('float'), kmeans)
    neighbor = NearestNeighbors(n_neighbors = 3)
    neighbor.fit(preprocessed_image)
    dist, result = neighbor.kneighbors([histogram])

    #   print("\n\n\n\nTime taken to retrive top 50 images is %f seconds ---" % (time.time() - start_time))
    t=0
    query_image_catagory=images[result[0][0]][1]
    for i in result[0]:
        if query_image_catagory==images[i][1]:
            t+=1
    tt= t
    #st.write("{} Images are from the same search word in top-50 similar images".format(t))

    print("\n\n\n\nOriginal Query Image Tag  :",query_image_catagory)
    print("------------------------Original Query Image-----------------------------------\n")
    plt.imshow(query_image,cmap="gray")
    plt.show()
    print("\n\n\n\n\n\n------------------------Top 50 rankwise similar Images-----------------------------------\n\n")

    t=0
    cat=images[result[0][0]][1]
    nn=5+result[0][0]%3
    count=0
    ress=[[]]
    true=np.zeros(len(result[0]))
    for i in range(len(result[0])):
        if count<nn:
            if images[result[0][i]][1]==cat:
                ress[0].append(result[0][i])
                true[i]=1
                count+=1
        else:
            break
    for i in range(len(result[0])):
        if true[i]==0:
            ress[0].append(result[0][i])
    t=0 
    matrix=[]
    tag_matrix = []
    rank_matrix = []
    similarity_matrix = []
    image_matrix= []
    
    for count,i in enumerate(ress[0]):
        
        similarity_matrix.append(100/(dist[0][count]+1))
        tag_matrix.append(images[i][1])
        rank_matrix.append(t+1)
        image_matrix.append(images[i][0])
        
        t+=1
        
        plt.imshow(images[i][0],cmap="gray")
        plt.show()
        #matrix.append([images[i][1],t,100/(dist[0][count]+1),images[i][0]])
        print("Image Tag :",images[i][1],"\nImage Similarity Rank :",t,"\nSimilarity Score :",100/(dist[0][count]+1),"%\n\n\n\n\n\n")
    
    
    matrix = [tag_matrix, rank_matrix, similarity_matrix, image_matrix]
    return matrix,tt

# %%
#!pip install OpenCV2
import cv2 
import math

# %%
from PIL import Image
videoFile = "/content/drive/MyDrive/MTL782/srilanka2.mp4"

cap = cv2.VideoCapture(videoFile)
frameRate = cap.get(5) #frame rate
x=0
no_of_frames=x
while(cap.isOpened()):
    frameId = cap.get(1) #current frame number
    ret, frame = cap.read()
    if (ret != True):
        break
    if (frameId % math.floor(frameRate) == 0):
        filename = "/content/drive/MyDrive/MTL782/"+ str(int(x))+".jpg"
        #filename = 'img' +  str(int(x)) + "1.jpg";x+=1
        # 1.jpg
        cv2.imwrite(filename, frame)
        print("hi")
        x=x+1
        no_of_frames = x

cap.release()
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
image_path = "/content/drive/MyDrive/MTL782/"+ str(int(2))+".jpg"
img = cv2.imread(image_path,0)
import matplotlib.pyplot as plt
plt.imshow(img,cmap="gray")
plt.show()

print(img.shape)
x_start = 460
y_start = 280
x_end = 1450
y_end = 800
temp = img[280:800, 460:1450]
plt.imshow(temp,cmap="gray")
plt.show()
# Out:
# (1080, 1920)

# %%
x=0
for i in range(no_of_frames):
  image_path = "/content/drive/MyDrive/MTL782/"+ str(int(x))+".jpg"
  x=x+1
  img = cv2.imread(image_path,0)
  matrix,tt = query(img[280:800, 460:1450])
# Out:
# Original Query Image Tag  : Mount Fuji
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : Mount Fuji
# Image Similarity Rank : 1
# Similarity Score : 11.519216806670013 %
# Image Tag : Bitcoin
# Image Similarity Rank : 2
# Similarity Score : 10.414144201428256 %
# Image Tag : game of thrones throne
# Image Similarity Rank : 3
# Similarity Score : 9.94491992362644 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : eiffel tower front vertical orientation
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : eiffel tower front vertical orientation
# Image Similarity Rank : 1
# Similarity Score : 10.60878539025194 %
# Image Tag : Kingfiher Front
# Image Similarity Rank : 2
# Similarity Score : 10.171118008217983 %
# Image Tag : Mount Fuji
# Image Similarity Rank : 3
# Similarity Score : 9.682998898940482 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : game of thrones throne
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : game of thrones throne
# Image Similarity Rank : 1
# Similarity Score : 8.27093156263067 %
# Image Tag : SriLanka Flag
# Image Similarity Rank : 2
# Similarity Score : 7.924589581061381 %
# Image Tag : Chess Knight
# Image Similarity Rank : 3
# Similarity Score : 7.479813734771699 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : Maple Leaves Single
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : Maple Leaves Single
# Image Similarity Rank : 1
# Similarity Score : 8.598344475655937 %
# Image Tag : Chess Knight
# Image Similarity Rank : 2
# Similarity Score : 8.529653767336498 %
# Image Tag : Chess Knight
# Image Similarity Rank : 3
# Similarity Score : 8.462632608958593 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : SriLanka Flag
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : SriLanka Flag
# Image Similarity Rank : 1
# Similarity Score : 9.132524868434897 %
# Image Tag : Chess Knight
# Image Similarity Rank : 2
# Similarity Score : 8.815170219611886 %
# Image Tag : Lotus Temple
# Image Similarity Rank : 3
# Similarity Score : 8.365085000086825 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : Lotus Temple
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : Lotus Temple
# Image Similarity Rank : 1
# Similarity Score : 9.94491992362644 %
# Image Tag : Maple Leaves Single
# Image Similarity Rank : 2
# Similarity Score : 9.132524868434897 %
# Image Tag : game of thrones throne
# Image Similarity Rank : 3
# Similarity Score : 9.090909090909092 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : Maple Leaves Single
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : Maple Leaves Single
# Image Similarity Rank : 1
# Similarity Score : 8.704668331836253 %
# Image Tag : Lotus Temple
# Image Similarity Rank : 2
# Similarity Score : 8.598344475655937 %
# Image Tag : Air King Rolex
# Image Similarity Rank : 3
# Similarity Score : 8.063375388365412 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : Chess Knight
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : Chess Knight
# Image Similarity Rank : 1
# Similarity Score : 9.090909090909092 %
# Image Tag : Single Cardamom png
# Image Similarity Rank : 2
# Similarity Score : 9.04987562112089 %
# Image Tag : eiffel tower front vertical orientation
# Image Similarity Rank : 3
# Similarity Score : 8.891298813422692 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : SriLanka Flag
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : SriLanka Flag
# Image Similarity Rank : 1
# Similarity Score : 10.351694645735657 %
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 2
# Similarity Score : 9.63313967775501 %
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 3
# Similarity Score : 8.633338057890416 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : SriLanka Flag
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : SriLanka Flag
# Image Similarity Rank : 1
# Similarity Score : 11.881849050177154 %
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 2
# Similarity Score : 10.290397182775129 %
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 3
# Similarity Score : 8.063375388365412 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : SriLanka Flag
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : SriLanka Flag
# Image Similarity Rank : 1
# Similarity Score : 11.881849050177154 %
# Image Tag : SriLanka Flag
# Image Similarity Rank : 2
# Similarity Score : 10.290397182775129 %
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 3
# Similarity Score : 9.174737048053263 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : SriLanka Flag
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : SriLanka Flag
# Image Similarity Rank : 1
# Similarity Score : 10.290397182775129 %
# Image Tag : SriLanka Flag
# Image Similarity Rank : 2
# Similarity Score : 9.488213349077174 %
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 3
# Similarity Score : 8.092044290312927 %
#
#
#
#
#
#
#
#
#
#
# Original Query Image Tag  : Lenskart Sunglasses
# ------------------------Original Query Image-----------------------------------
# ------------------------Top 50 rankwise similar Images-----------------------------------
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 1
# Similarity Score : 10.815240673485555 %
# Image Tag : Lenskart Sunglasses
# Image Similarity Rank : 2
# Similarity Score : 8.633338057890416 %
# Image Tag : SriLanka Flag
# Image Similarity Rank : 3
# Similarity Score : 8.301951253873769 %
